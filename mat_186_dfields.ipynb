# %%
# import all the packages we need
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

# this makes sure the images don't come out looking muddy on 
# retina displays (which your computer probably uses)
# Update 07/18/22: got retina working with updates thanks to 
# https://stackoverflow.com/questions/54312924/what-is-matplotlibs-retina-display-mode
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
tmax = 2
xmax = 2.
samples_per_axis = 13 # number of sample points per axis

# create mesh grid of data points where we sample direction field/RHS of ODE
t,x = np.meshgrid(np.linspace(-tmax,tmax,samples_per_axis),np.linspace(1,xmax,samples_per_axis))

# define direction field sampled at mesh grid of data points
u = 1.
v = t/x

fig, ax = plt.subplots()

# define all plot parameters + ensure axis labels all look nice. 
# Lots of this stuff is purely optional. 
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

textcolor = 'k'

#plt.xlim([-0.05, xmax])
#plt.ylim([0, ymax])

plt.xlabel(r"$t$", fontsize=32, color = textcolor)
plt.ylabel(r"$x$", fontsize=32, color = textcolor)

plt.tick_params(axis='x', which='both', top='off', color = textcolor)
plt.xticks(fontsize=24, rotation=0, color = textcolor)
plt.tick_params(axis='y', which='both', right='off', color = textcolor)
plt.yticks(fontsize=24, rotation=0, color = textcolor)


# sketch arrows of ODE's direction field. 
plt.quiver(t,x,u,v, color='xkcd:cerulean', linewidth=4)

#"""
# sketch some integral curves
tt = np.linspace(-tmax, tmax)
plt.plot(tt, np.sqrt(1.**2+tt**2), color='xkcd:raspberry')
plt.plot(tt, np.sqrt(1.5**2+tt**2), color='xkcd:raspberry')
plt.plot(tt, np.sqrt(1.25**2+tt**2), color='xkcd:raspberry')
#"""

# adjust figure aspect ratio and size for maximum clarity
#ax.set_aspect(1.)
plt.rcParams['figure.figsize'] = [8, 8]
plt.rcParams["axes.edgecolor"] = 'k'

plt.xlim([-1.05*tmax, 1.05*tmax])
plt.ylim([1., xmax])

plt.savefig('dfields_option_a_with_curves'+'.jpg', dpi=900)

# finally, show the plot
plt.show()

# %%
tmax = 2.
xmax = 2.
samples_per_axis = 13 # number of sample points per axis

# create mesh grid of data points where we sample direction field/RHS of ODE
t,x = np.meshgrid(np.linspace(-tmax,tmax,samples_per_axis),np.linspace(1,xmax,samples_per_axis))

# define direction field sampled at mesh grid of data points
u = 1.
v = t**2/x

fig, ax = plt.subplots()

# define all plot parameters + ensure axis labels all look nice. 
# Lots of this stuff is purely optional. 
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

textcolor = 'k'

#plt.xlim([-0.05, xmax])
#plt.ylim([0, ymax])

plt.xlabel(r"$t$", fontsize=32, color = textcolor)
plt.ylabel(r"$x$", fontsize=32, color = textcolor)

plt.tick_params(axis='x', which='both', top='off', color = textcolor)
plt.xticks(fontsize=24, rotation=0, color = textcolor)
plt.tick_params(axis='y', which='both', right='off', color = textcolor)
plt.yticks(fontsize=24, rotation=0, color = textcolor)


# sketch arrows of ODE's direction field. 
plt.quiver(t,x,u,v, color='xkcd:cerulean', linewidth=4)

"""
# sketch some integral curves
tt = np.linspace(-tmax, tmax)
a = 2./3.
plt.plot(tt, np.sqrt(1.**2+a*tt**3), color='xkcd:raspberry')
plt.plot(tt, np.sqrt(1.5**2+a*tt**3), color='xkcd:raspberry')
plt.plot(tt, np.sqrt(1.25**2+a*tt**3), color='xkcd:raspberry')
"""

# adjust figure aspect ratio and size for maximum clarity
#ax.set_aspect(1.)
plt.rcParams['figure.figsize'] = [8, 8]

plt.rcParams["axes.edgecolor"] = 'k'

plt.xlim([-1.05*tmax, 1.05*tmax])
plt.ylim([1., xmax])

plt.savefig('dfields_option_b'+'.jpg', dpi=900)


# finally, show the plot
plt.show()

# %%
tmax = 2.
xmax = 2.
samples_per_axis = 15 # number of sample points per axis

# create mesh grid of data points where we sample direction field/RHS of ODE
t,x = np.meshgrid(np.linspace(-tmax,tmax,samples_per_axis),np.linspace(1,xmax,samples_per_axis))

# define direction field sampled at mesh grid of data points
u = 1.
v = x/(t)

fig, ax = plt.subplots()

# define all plot parameters + ensure axis labels all look nice. 
# Lots of this stuff is purely optional. 
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

textcolor = 'k'

#plt.xlim([-0.05, xmax])
#plt.ylim([0, ymax])

plt.xlabel(r"$t$", fontsize=32, color = textcolor)
plt.ylabel(r"$x$", fontsize=32, color = textcolor)

plt.tick_params(axis='x', which='both', top='off', color = textcolor)
plt.xticks(fontsize=24, rotation=0, color = textcolor)
plt.tick_params(axis='y', which='both', right='off', color = textcolor)
plt.yticks(fontsize=24, rotation=0, color = textcolor)


# sketch arrows of ODE's direction field. 
plt.quiver(t,x,u,v, color='xkcd:cerulean', linewidth=4)

# adjust figure aspect ratio and size for maximum clarity
#ax.set_aspect(1.)
plt.rcParams['figure.figsize'] = [8, 8]

plt.rcParams["axes.edgecolor"] = 'k'

plt.xlim([-1.05*tmax, 1.05*tmax])
plt.ylim([1., xmax])

plt.savefig('dfields_option_c'+'.jpg', dpi=900)

# finally, show the plot
plt.show()
# Out:
# /tmp/ipykernel_20815/2424377269.py:10: RuntimeWarning: divide by zero encountered in divide
#   v = x/(t)

# %%
tmax = 2.
xmax = 2.
samples_per_axis = 15 # number of sample points per axis

# create mesh grid of data points where we sample direction field/RHS of ODE
t,x = np.meshgrid(np.linspace(-tmax,tmax,samples_per_axis),np.linspace(1,xmax,samples_per_axis))

# define direction field sampled at mesh grid of data points
u = 1.
v = x*t*np.cos(t)

fig, ax = plt.subplots()

# define all plot parameters + ensure axis labels all look nice. 
# Lots of this stuff is purely optional. 
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

textcolor = 'k'

#plt.xlim([-0.05, xmax])
#plt.ylim([0, ymax])

plt.xlabel(r"$t$", fontsize=32, color = textcolor)
plt.ylabel(r"$x$", fontsize=32, color = textcolor)

plt.tick_params(axis='x', which='both', top='off', color = textcolor)
plt.xticks(fontsize=24, rotation=0, color = textcolor)
plt.tick_params(axis='y', which='both', right='off', color = textcolor)
plt.yticks(fontsize=24, rotation=0, color = textcolor)


# sketch arrows of ODE's direction field. 
plt.quiver(t,x,u,v, color='xkcd:cerulean', linewidth=4)

"""
# sketch some integral curves
tt = np.linspace(-tmax, tmax)
a = 2./3.
plt.plot(tt, np.sqrt(1.**2+a*tt**3), color='xkcd:raspberry')
plt.plot(tt, np.sqrt(1.5**2+a*tt**3), color='xkcd:raspberry')
plt.plot(tt, np.sqrt(2**2+a*tt**3), color='xkcd:raspberry')
plt.plot(tt, np.sqrt(2.5**2+a*tt**3), color='xkcd:raspberry')
plt.plot(tt, np.sqrt(3**2+a*tt**3), color='xkcd:raspberry')
"""

# adjust figure aspect ratio and size for maximum clarity
#ax.set_aspect(1.)
plt.rcParams['figure.figsize'] = [8, 8]

plt.rcParams["axes.edgecolor"] = 'k'

plt.xlim([-1.05*tmax, 1.05*tmax])
plt.ylim([1., xmax])

plt.savefig('dfields_option_d'+'.jpg', dpi=900)


# finally, show the plot
plt.show()
